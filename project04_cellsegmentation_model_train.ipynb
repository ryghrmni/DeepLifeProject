# %% [markdown]
# <a href="https://colab.research.google.com/github/ryghrmni/DeepLifeProject/blob/main/project04_cellsegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project : Cell image segmentation projects**
#
#
# ---
#
#
#
# **Team** (Alphabetical order)**:** Arvin Jafari, Delnavaz Fotouhi, Reza Ghahremani
#
# **University:** Università degli Studi di Milano
#
# ** This course is provided by 4EU+ alliance of European universities, Heidelberg University will coordinate a joint course on Applications of Deep Learning in Life Sciences (DeepLife) involving the universities of Paris-Sorbonne, Warsaw, Prague, Milano and Heidelberg.
#
# **Reference:** https://deeplife4eu.github.io/
#
#
# ---
#
#
#
# Cell segmentation is usually the first step for downstream single-cell analysis in microscopy image-based biology and biomedical research. Deep learning has been widely used for cell-image segmentation.
# The CellSeg competition aims to benchmark cell segmentation methods that could be applied to various microscopy images across multiple imaging platforms and tissue types for cell Segmentation. The  Dataset challenge organizers provide contains both labeled images and unlabeled ones.
# The “2018 Data Science Bowl” Kaggle competition provides cell images and their masks for training cell/nuclei segmentation models.
#
# ### Project Description
#
# In the field of (bio-medical) image processing, segmentation of images is typically performed via U-Nets [1,2].
#
# A U-Net consists of an encoder - a series of convolution and pooling layers which reduce the spatial resolution of the input, followed by a decoder - a series of transposed convolution and upsampling layers which increase the spatial resolution of the input. The encoder and decoder are connected by a bottleneck layer which is responsible for reducing the number of channels in the input.
# The key innovation of U-Net is the addition of skip connections that connect the contracting path to the corresponding layers in the expanding path, allowing the network to recover fine-grained details lost during downsampling.
#
# <img src='https://production-media.paperswithcode.com/methods/Screen_Shot_2020-07-07_at_9.08.00_PM_rpNArED.png' width="400"/>
#
#
# At this [link](https://rpubs.com/eR_ic/unet), you find an R implementation of basic U-Nets. At this [link](https://github.com/zhixuhao/unet), you find a Keras implementation of UNets.
# Other implementations of more advanced UNets are also made available in [2] at these links: [UNet++](https://github.com/MrGiovanni/UNetPlusPlus)
# and by the CellSeg organizers as baseline models: [https://neurips22-cellseg.grand-challenge.org/baseline-and-tutorial/](https://neurips22-cellseg.grand-challenge.org/baseline-and-tutorial/)
#
# ### Project aim
#
# The aim of the project is to download the cell images (preferably from the “2018 Data Science Bowl” competition) and assess the performance of an UNet or any other Deep model for cell segmentation.
# Students are free to choose any model, as long as they are able to explain their rationale, architecture, strengths and weaknesses.
#
#
#
# ### References
#
# [1] Ronneberger, O., Fischer, P., Brox, T. (2015). U-Net: Convolutional Networks for Biomedical Image Segmentation. In: Navab, N., Hornegger, J., Wells, W., Frangi, A. (eds) Medical Image Computing and Computer-Assisted Intervention – MICCAI 2015. MICCAI 2015. Lecture Notes in Computer Science(), vol 9351. Springer, Cham. https://doi.org/10.1007/978-3-319-24574-4_28
#
# [2] Long, F. Microscopy cell nuclei segmentation with enhanced U-Net. BMC Bioinformatics 21, 8 (2020). https://doi.org/10.1186/s12859-019-3332-1

# %% [markdown]
# ## **Step 1: Data Preparation**

# %% [markdown]
# **1.1. Install and Upgrade Kaggle Package**
#
# The Kaggle Python package was installed and upgraded to ensure we have the latest version with all necessary functionalities.

# %%
# !pip install --upgrade kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.12)
# Collecting kaggle
#   Downloading kaggle-1.6.14.tar.gz (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 949.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.6.14-py3-none-any.whl size=105119 sha256=f6f06f85311b22ed1b1a943a864b7d1c222a85314d5ac28887844bb4999b15b8
#   Stored in directory: /root/.cache/pip/wheels/d7/54/06/8a8f40cb39536605feb9acaacd0237a95eba39e5065e6392f4
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.6.12
#     Uninstalling kaggle-1.6.12:
#       Successfully uninstalled kaggle-1.6.12
# Successfully installed kaggle-1.6.14

# %% [markdown]
# **1.2. Verify and Create Kaggle Directory**
#
# We verified if the ~/.kaggle directory exists. If not, the directory was created to store the Kaggle API credentials.

# %%
import os

# Verify ~/.kaggle directory exists
kaggle_dir = os.path.expanduser('~/.kaggle')
if not os.path.exists(kaggle_dir):
    os.makedirs(kaggle_dir)
    print("Directory created: ~/.kaggle")
else:
    print("Directory already exists: ~/.kaggle")
# Out:
# Directory created: ~/.kaggle

# %% [markdown]
# **1.3. Copy Kaggle JSON to Kaggle Directory**
#
# The kaggle.json file, which contains the API credentials, was copied to the ~/.kaggle directory. Permissions were set to ensure the file is secure.

# %%
import shutil

# Step 2: Copy kaggle.json to ~/.kaggle directory
kaggle_json_path = 'kaggle.json'  # Update this path if necessary
target_path = os.path.join(kaggle_dir, 'kaggle.json')

if os.path.exists(kaggle_json_path):
    shutil.copy(kaggle_json_path, target_path)
    os.chmod(target_path, 0o600)
    print("kaggle.json has been copied to ~/.kaggle and permissions set.")
else:
    print("kaggle.json not found in the current directory.")
# Out:
# kaggle.json not found in the current directory.

# %% [markdown]
# **1.4. Set Environment Variables for Kaggle API**
#
# Environment variables for the Kaggle username and key were set to enable authentication for API requests.
#
# **reference:** https://www.kaggle.com/docs/api

# %%
import os
os.environ['KAGGLE_USERNAME'] = input()
os.environ['KAGGLE_KEY'] = input()
# Out:
# delnavazfotouhi
# 11e6676f4ec9d4e1817128d2f8557c5d

# %% [markdown]
# **1.5. Download Dataset from Kaggle and Extract Dataset**
#
# The dataset for the Data Science Bowl 2018 competition was downloaded using the Kaggle API. The downloaded zip file was extracted into a directory named data.

# %%
# !kaggle competitions download -c data-science-bowl-2018
# Out:
# Downloading data-science-bowl-2018.zip to /content
# 100% 357M/358M [00:04<00:00, 82.1MB/s]
# 100% 358M/358M [00:04<00:00, 93.2MB/s]

# %%
# !unzip data-science-bowl-2018.zip -d data
# Out:
# Archive:  data-science-bowl-2018.zip
#   inflating: data/stage1_sample_submission.csv.zip
#   inflating: data/stage1_solution.csv.zip
#   inflating: data/stage1_test.zip
#   inflating: data/stage1_train.zip
#   inflating: data/stage1_train_labels.csv.zip
#   inflating: data/stage2_sample_submission_final.csv.zip
#   inflating: data/stage2_test_final.zip

# %% [markdown]
# **1.6. Navigate to Data Directory and Extract All Files and List Directory Contents**
#
# Changed the current working directory to data and extracted all zip files within it. The original zip files were then deleted. Finally, we listed the contents of the data directory to confirm the successful extraction of the dataset files.

# %%
cd data
# Out:
# /content/data

# %%
# !for file in *.zip; do unzip -q "$file" -d "${file%%.*}" && rm "$file"; done

# %%
ls
# Out:
# stage1_sample_submission/  stage1_test/   stage1_train_labels/             stage2_test_final/
# stage1_solution/           stage1_train/  stage2_sample_submission_final/

# %% [markdown]
# ## **Step 2: Data Preprocessing**

# %% [markdown]
# **2.1. Stretch Contrast Function**
#
# This function stretches the contrast of an image to utilize the full range of pixel values (0 to 255).

# %%
def stretch_contrast(image):
    min_val = np.min(image)
    max_val = np.max(image)
    stretched_image = (image - min_val) * (255.0 / (max_val - min_val))
    return stretched_image.astype(np.uint8)

# %% [markdown]
# **2.2. Load Data Function**
#
# This function loads the images and masks from the specified base path, stretches the contrast of the images, and stores them in lists.

# %%
def load_data(base_path):
    images = []
    masks = []
    sample_names = []

    sample_folders = [os.path.join(base_path, folder) for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))]

    for sample_folder in sample_folders:
        sample_name = os.path.basename(sample_folder)
        image_path = os.path.join(sample_folder, 'images', f'{sample_name}.png')
        masks_path = os.path.join(sample_folder, 'masks')

        image = Image.open(image_path)
        image = np.array(image)
        stretched_image = stretch_contrast(image)
        images.append(stretched_image)
        sample_names.append(sample_name)

        mask_files = [os.path.join(masks_path, mask_file) for mask_file in os.listdir(masks_path) if mask_file.endswith('.png')]
        sample_masks = [np.array(Image.open(mask_file).convert('L')) for mask_file in mask_files]
        masks.append(sample_masks)

    return images, masks, sample_names

# %% [markdown]
# **2.3. Merge Masks Function**
#
# This function merges multiple masks by adding the values of corresponding pixels.

# %%
def merge_masks(masks):
    merged_mask = np.zeros_like(masks[0], dtype=np.uint8)
    for mask in masks:
        mask_uint8 = mask.astype(np.uint8)
        merged_mask += mask_uint8
    return merged_mask

# %% [markdown]
# **2.4. Example Usage**

# %%
import os
import shutil
import random

# Define the source directory
source_dir = "/content/data/stage1_train"

# Define the destination directory
dest_dir = "/content/data/toy_data"

# Create the destination directory if it doesn't exist
os.makedirs(dest_dir, exist_ok=True)

# Get a list of all folders in the source directory
folders = os.listdir(source_dir)

# Randomly select 50 folders
selected_folders = random.sample(folders, 50)

# Copy selected folders to the destination directory
for folder in selected_folders:
    src = os.path.join(source_dir, folder)
    dst = os.path.join(dest_dir, folder)
    shutil.copytree(src, dst)

print("Selected folders have been copied to the 'toy_data' folder.")
# Out:
# Selected folders have been copied to the 'toy_data' folder.

# %%
cd /content/data/toy_data
# Out:
# /content/data/toy_data

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Example usage:
base_path = '/content/data/toy_data'
images, masks, sample_names = load_data(base_path)

# Access the first sample
first_sample_index = 0
first_sample_name = sample_names[first_sample_index]
first_sample_image = images[first_sample_index]
first_sample_masks = masks[first_sample_index]

# Print the sample name and display the image
print(f'First sample name: {first_sample_name}')
plt.figure()
plt.imshow(first_sample_image)
plt.title(f'Image: {first_sample_name}')
plt.axis('off')
plt.show()

# Display the masks
for i, mask in enumerate(first_sample_masks):
    plt.figure()
    plt.imshow(mask, cmap='gray')
    plt.title(f'Mask {i + 1} for sample {first_sample_name}')
    plt.axis('off')
    plt.show()

# Merge and display the masks
merged_mask = merge_masks(first_sample_masks)

plt.figure()
plt.imshow(merged_mask, cmap='gray')
plt.title(f'Merged Mask for sample {first_sample_name}')
plt.axis('off')
plt.show()
# Out:
# First sample name: 91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379

# %% [markdown]
# **2.5. Mask Merging**
#
# The masks are merged to create a single composite mask for each sample, which is then saved for further analysis.

# %%
def stretch_contrast(image):
    min_val = np.min(image)
    max_val = np.max(image)
    stretched_image = (image - min_val) * (255.0 / (max_val - min_val))
    return stretched_image.astype(np.uint8)

def load_data(base_path):
    images = []
    masks = []
    sample_names = []
    sample_folders = []

    # Get all sample folders
    sample_folders = [os.path.join(base_path, folder) for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))]

    for sample_folder in sample_folders:
        sample_name = os.path.basename(sample_folder)
        image_path = os.path.join(sample_folder, 'images', f'{sample_name}.png')
        masks_path = os.path.join(sample_folder, 'masks')

        # Load the image and stretch contrast
        image = Image.open(image_path)
        image = np.array(image)
        stretched_image = stretch_contrast(image)
        images.append(stretched_image)
        sample_names.append(sample_name)

        # Load all masks for this sample
        mask_files = [os.path.join(masks_path, mask_file) for mask_file in os.listdir(masks_path) if mask_file.endswith('.png')]
        sample_masks = [np.array(Image.open(mask_file).convert('L')) for mask_file in mask_files]
        masks.append(sample_masks)

    return images, masks, sample_names, sample_folders

# This function merges multiple masks by adding the values of corresponding pixels.
def merge_masks(masks):
    merged_mask = np.zeros_like(masks[0], dtype=np.uint8)
    for mask in masks:
        mask_uint8 = mask.astype(np.uint8)
        merged_mask += mask_uint8
    return merged_mask

# This function saves the merged mask as an image file in the 'merged_masks' folder within the sample folder.
def save_merged_mask(merged_mask, sample_folder):
    merged_masks_dir = os.path.join(sample_folder, 'merged_masks')
    os.makedirs(merged_masks_dir, exist_ok=True)
    sample_name = os.path.basename(sample_folder)
    output_path = os.path.join(merged_masks_dir, f"{sample_name}_merged_mask.png")
    merged_mask_image = Image.fromarray(merged_mask)
    merged_mask_image.save(output_path)
    print(f"Merged mask saved at: {output_path}")

# This function loads the data, merges the masks for each sample, and saves the merged masks in the corresponding folders.
def process_and_save_merged_masks(base_path):
    images, masks, sample_names, sample_folders = load_data(base_path)
    for sample_name, sample_masks, sample_folder in zip(sample_names, masks, sample_folders):
        merged_mask = merge_masks(sample_masks)
        save_merged_mask(merged_mask, sample_folder)

# %%
#Example Usage
merged_mask = merge_masks(first_sample_masks)

# Display the merged mask
plt.figure()
plt.imshow(merged_mask, cmap='gray')
plt.title(f'Merged Mask for sample {first_sample_name}')
plt.axis('off')
plt.show()

# %%
base_path = '/content/data/toy_data'
process_and_save_merged_masks(base_path)
# Out:
# Merged mask saved at: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379/merged_masks/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask.png
# Merged mask saved at: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask.png
# Merged mask saved at: /content/data/toy_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868/merged_masks/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_merged_mask.png
# Merged mask saved at: /content/data/toy_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee/merged_masks/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_merged_mask.png
# Merged mask saved at: /content/data/toy_data/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47/merged_masks/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47_merged_mask.png
# Merged mask saved at: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380/merged_masks/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask.png
# Merged mask saved at: /content/data/toy_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55/merged_masks/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_merged_mask.png
# Merged mask saved at: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066/merged_masks/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask.png
# Merged mask saved at: /content/data/toy_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5/merged_masks/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_merged_mask.png
# Merged mask saved at: /content/data/toy_data/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552/merged_masks/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552_merged_mask.png
# Merged mask saved at: /content/data/toy_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932/merged_masks/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_merged_mask.png
# Merged mask saved at: /content/data/toy_data/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96/merged_masks/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96_merged_mask.png
# Merged mask saved at: /content/data/toy_data/7773ac91af61ed041701b7c3b649598e3707cf04c0577f464fd31be687f538fe/merged_masks/7773ac91af61ed041701b7c3b649598e3707cf04c0577f464fd31be687f538fe_merged_mask.png
# Merged mask saved at: /content/data/toy_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991/merged_masks/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_merged_mask.png
# Merged mask saved at: /content/data/toy_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f/merged_masks/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_merged_mask.png
# Merged mask saved at: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a/merged_masks/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask.png
# Merged mask saved at: /content/data/toy_data/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53/merged_masks/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_merged_mask.png
# Merged mask saved at: /content/data/toy_data/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8/merged_masks/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_merged_mask.png
# Merged mask saved at: /content/data/toy_data/58cc121d37fb7f1b4a5252024d88415936781e540252b8f734faeedd29b682d5/merged_masks/58cc121d37fb7f1b4a5252024d88415936781e540252b8f734faeedd29b682d5_merged_mask.png
# Merged mask saved at: /content/data/toy_data/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97/merged_masks/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_merged_mask.png
# Merged mask saved at: /content/data/toy_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48/merged_masks/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_merged_mask.png
# Merged mask saved at: /content/data/toy_data/fe80a2cf3c93dafad8c364fdd1646b0ba4db056cdb7bdb81474f957064812bba/merged_masks/fe80a2cf3c93dafad8c364fdd1646b0ba4db056cdb7bdb81474f957064812bba_merged_mask.png
# Merged mask saved at: /content/data/toy_data/ff3407842ada5bc18be79ae453e5bdaa1b68afc842fc22fa618ac6e6599d0bb3/merged_masks/ff3407842ada5bc18be79ae453e5bdaa1b68afc842fc22fa618ac6e6599d0bb3_merged_mask.png
# Merged mask saved at: /content/data/toy_data/dbe5ad05b6f87018159a3228c1d1725892a1bfb9fa9f8fcc2e8bfe70d69d0355/merged_masks/dbe5ad05b6f87018159a3228c1d1725892a1bfb9fa9f8fcc2e8bfe70d69d0355_merged_mask.png
# Merged mask saved at: /content/data/toy_data/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745/merged_masks/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_merged_mask.png
# Merged mask saved at: /content/data/toy_data/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311/merged_masks/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_merged_mask.png
# Merged mask saved at: /content/data/toy_data/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6/merged_masks/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_merged_mask.png
# Merged mask saved at: /content/data/toy_data/c44ed955eb2e5c8d820b01477e122b32eff6dd475343e11229c33d8af3473b22/merged_masks/c44ed955eb2e5c8d820b01477e122b32eff6dd475343e11229c33d8af3473b22_merged_mask.png
# Merged mask saved at: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d/merged_masks/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask.png
# Merged mask saved at: /content/data/toy_data/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51/merged_masks/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_merged_mask.png
# Merged mask saved at: /content/data/toy_data/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b/merged_masks/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_merged_mask.png
# Merged mask saved at: /content/data/toy_data/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03/merged_masks/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_merged_mask.png
# Merged mask saved at: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2/merged_masks/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask.png
# Merged mask saved at: /content/data/toy_data/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63/merged_masks/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_merged_mask.png
# Merged mask saved at: /content/data/toy_data/305a8baaf726d7c9e695bff31d3a6a61445999a4732f0a3e6174dc9dcbe43931/merged_masks/305a8baaf726d7c9e695bff31d3a6a61445999a4732f0a3e6174dc9dcbe43931_merged_mask.png
# Merged mask saved at: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f/merged_masks/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask.png
# Merged mask saved at: /content/data/toy_data/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1/merged_masks/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_merged_mask.png
# Merged mask saved at: /content/data/toy_data/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff/merged_masks/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_merged_mask.png
# Merged mask saved at: /content/data/toy_data/03f583ec5018739f4abb9b3b4a580ac43bd933c4337ad8877aa18b1dfb59fc9a/merged_masks/03f583ec5018739f4abb9b3b4a580ac43bd933c4337ad8877aa18b1dfb59fc9a_merged_mask.png
# Merged mask saved at: /content/data/toy_data/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52/merged_masks/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_merged_mask.png
# Merged mask saved at: /content/data/toy_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819/merged_masks/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_merged_mask.png
# Merged mask saved at: /content/data/toy_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45/merged_masks/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_merged_mask.png
# Merged mask saved at: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e/merged_masks/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask.png
# Merged mask saved at: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49/merged_masks/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask.png
# Merged mask saved at: /content/data/toy_data/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf/merged_masks/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_merged_mask.png
# Merged mask saved at: /content/data/toy_data/d7db360fabfce9828559a21f6bffff589ae868e0dc6101d7c1212de34a25e3cb/merged_masks/d7db360fabfce9828559a21f6bffff589ae868e0dc6101d7c1212de34a25e3cb_merged_mask.png
# Merged mask saved at: /content/data/toy_data/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e/merged_masks/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_merged_mask.png
# Merged mask saved at: /content/data/toy_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec/merged_masks/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_merged_mask.png
# Merged mask saved at: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7/merged_masks/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask.png
# Merged mask saved at: /content/data/toy_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b/merged_masks/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_merged_mask.png

# %% [markdown]
# ## **3. Data Augmentation**

# %%
# !pip install imgaug
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2024.5.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)

# %%
import os
import numpy as np
from PIL import Image
import imgaug.augmenters as iaa

# %%
def load_image(image_path):
    """
    Load an image from the specified path and return it as a numpy array.
    """
    image = Image.open(image_path)
    return np.array(image)

def save_image(image_array, output_path):
    """
    Save a numpy array as an image to the specified path.
    """
    image = Image.fromarray(image_array)
    image.save(output_path)

def stretch_contrast(image):
    """
    Stretch the contrast of an image to utilize the full range of pixel values (0 to 255).
    """
    min_val = np.min(image)
    max_val = np.max(image)
    stretched_image = (image - min_val) * (255.0 / (max_val - min_val))
    return stretched_image.astype(np.uint8)

def merge_masks(masks):
    """
    Merge masks by adding the values of corresponding pixels.
    """
    merged_mask = np.zeros_like(masks[0], dtype=np.uint8)
    for mask in masks:
        merged_mask += mask.astype(np.uint8)
    return merged_mask

def augment_images_and_masks(images, masks, augmenters):
    """
    Apply augmentations to a list of images and masks in a synchronized manner.
    """
    deterministic_augmenters = augmenters.to_deterministic()
    aug_images = deterministic_augmenters(images=images)
    aug_masks = deterministic_augmenters(images=masks)
    return aug_images, aug_masks

def create_augmented_folder(base_path, sample_name, num_augments=5):
    """
    Create augmented images for a given sample and save them in separate folders within the toy_data directory.
    """
    sample_folder = os.path.join(base_path, sample_name)
    images_path = os.path.join(sample_folder, 'images')
    masks_path = os.path.join(sample_folder, 'masks')

    # Load the image
    image_files = [os.path.join(images_path, f) for f in os.listdir(images_path) if f.endswith('.png')]
    image = load_image(image_files[0])
    images = [image]

    # Load masks
    mask_files = [os.path.join(masks_path, f) for f in os.listdir(masks_path) if f.endswith('.png')]
    masks = [load_image(mask_file) for mask_file in mask_files]

    # Merge masks
    merged_mask = merge_masks(masks)

    # Define augmentation pipeline
    augmenters = iaa.Sequential([
        iaa.Fliplr(0.5),  # horizontal flips
        iaa.Sometimes(1.0, iaa.Affine(rotate=[90, 180, 270])),
        iaa.Multiply((0.8, 1.2)),  # random brightness changes
        iaa.LinearContrast((0.75, 1.5)),  # random contrast changes
    ])

    # Generate and save augmented images and masks
    for i in range(num_augments):
        aug_images, aug_masks = augment_images_and_masks(images, [merged_mask], augmenters)

        # Create a subfolder for each augmented image and masks within the toy_data directory
        augmented_subfolder = os.path.join(base_path, f"{sample_name}_augmented_{i+1}")
        os.makedirs(augmented_subfolder, exist_ok=True)
        augmented_images_folder = os.path.join(augmented_subfolder, 'images')
        augmented_masks_folder = os.path.join(augmented_subfolder, 'merged_masks')
        os.makedirs(augmented_images_folder, exist_ok=True)
        os.makedirs(augmented_masks_folder, exist_ok=True)

        for j, aug_image in enumerate(aug_images):
            save_image(aug_image, os.path.join(augmented_images_folder, f"{sample_name}_aug_{i}_{j}.png"))
        for j, aug_mask in enumerate(aug_masks):
            save_image(aug_mask, os.path.join(augmented_masks_folder, f"{sample_name}_merged_mask_aug_{i}_{j}.png"))

    print(f"Augmented data saved in separate folders within toy_data for sample: {sample_name}")

# Apply augmentation to all sample folders in the base path
def augment_all_samples(base_path, num_augments=5):
    """
    Apply augmentation to all sample folders within the base path.

    Args:
    - base_path (str): Path to the base directory containing images and masks.
    - num_augments (int): Number of augmented images to generate per sample.
    """
    sample_folders = [folder for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))]

    for sample_name in sample_folders:
        create_augmented_folder(base_path, sample_name, num_augments)

# %%
base_path = '/content/data/toy_data'
augment_all_samples(base_path, num_augments=5)
# Out:
# Augmented data saved in separate folders within toy_data for sample: 91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379
# Augmented data saved in separate folders within toy_data for sample: 866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855
# Augmented data saved in separate folders within toy_data for sample: 648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868
# Augmented data saved in separate folders within toy_data for sample: ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee
# Augmented data saved in separate folders within toy_data for sample: 27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47
# Augmented data saved in separate folders within toy_data for sample: 094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380
# Augmented data saved in separate folders within toy_data for sample: f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55
# Augmented data saved in separate folders within toy_data for sample: 193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066
# Augmented data saved in separate folders within toy_data for sample: f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5
# Augmented data saved in separate folders within toy_data for sample: 00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552
# Augmented data saved in separate folders within toy_data for sample: c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932
# Augmented data saved in separate folders within toy_data for sample: bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96
# Augmented data saved in separate folders within toy_data for sample: 7773ac91af61ed041701b7c3b649598e3707cf04c0577f464fd31be687f538fe
# Augmented data saved in separate folders within toy_data for sample: 5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991
# Augmented data saved in separate folders within toy_data for sample: 958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f
# Augmented data saved in separate folders within toy_data for sample: f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a
# Augmented data saved in separate folders within toy_data for sample: 8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53
# Augmented data saved in separate folders within toy_data for sample: edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8
# Augmented data saved in separate folders within toy_data for sample: 58cc121d37fb7f1b4a5252024d88415936781e540252b8f734faeedd29b682d5
# Augmented data saved in separate folders within toy_data for sample: df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97
# Augmented data saved in separate folders within toy_data for sample: ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48
# Augmented data saved in separate folders within toy_data for sample: fe80a2cf3c93dafad8c364fdd1646b0ba4db056cdb7bdb81474f957064812bba
# Augmented data saved in separate folders within toy_data for sample: ff3407842ada5bc18be79ae453e5bdaa1b68afc842fc22fa618ac6e6599d0bb3
# Augmented data saved in separate folders within toy_data for sample: dbe5ad05b6f87018159a3228c1d1725892a1bfb9fa9f8fcc2e8bfe70d69d0355
# Augmented data saved in separate folders within toy_data for sample: 4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745
# Augmented data saved in separate folders within toy_data for sample: 5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311
# Augmented data saved in separate folders within toy_data for sample: aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6
# Augmented data saved in separate folders within toy_data for sample: c44ed955eb2e5c8d820b01477e122b32eff6dd475343e11229c33d8af3473b22
# Augmented data saved in separate folders within toy_data for sample: f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d
# Augmented data saved in separate folders within toy_data for sample: 449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51
# Augmented data saved in separate folders within toy_data for sample: bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b
# Augmented data saved in separate folders within toy_data for sample: e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03
# Augmented data saved in separate folders within toy_data for sample: 77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2
# Augmented data saved in separate folders within toy_data for sample: 8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63
# Augmented data saved in separate folders within toy_data for sample: 305a8baaf726d7c9e695bff31d3a6a61445999a4732f0a3e6174dc9dcbe43931
# Augmented data saved in separate folders within toy_data for sample: f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f
# Augmented data saved in separate folders within toy_data for sample: 76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1
# Augmented data saved in separate folders within toy_data for sample: 60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff
# Augmented data saved in separate folders within toy_data for sample: 03f583ec5018739f4abb9b3b4a580ac43bd933c4337ad8877aa18b1dfb59fc9a
# Augmented data saved in separate folders within toy_data for sample: 319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52
# Augmented data saved in separate folders within toy_data for sample: 4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819
# Augmented data saved in separate folders within toy_data for sample: 20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45
# Augmented data saved in separate folders within toy_data for sample: 00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e
# Augmented data saved in separate folders within toy_data for sample: 8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49
# Augmented data saved in separate folders within toy_data for sample: 2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf
# Augmented data saved in separate folders within toy_data for sample: d7db360fabfce9828559a21f6bffff589ae868e0dc6101d7c1212de34a25e3cb
# Augmented data saved in separate folders within toy_data for sample: 5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e
# Augmented data saved in separate folders within toy_data for sample: 29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec
# Augmented data saved in separate folders within toy_data for sample: d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7
# Augmented data saved in separate folders within toy_data for sample: 317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b

# %% [markdown]
# **Data Organization**

# %%
def create_folders(base_path):
    """
    Create images_data and masks_data folders in the specified base path.

    Args:
    - base_path (str): Path to the base directory where the new folders will be created.
    """
    images_data_path = os.path.join(base_path, 'images_data')
    masks_data_path = os.path.join(base_path, 'masks_data')

    os.makedirs(images_data_path, exist_ok=True)
    os.makedirs(masks_data_path, exist_ok=True)

    print(f"Created folders: {images_data_path} and {masks_data_path}")
    return images_data_path, masks_data_path

# %%
def copy_images_and_masks(base_path, images_data_path, masks_data_path):
    """
    Copy all images from images folders and all masks from merged_masks folders
    inside the toy_data folder to images_data and masks_data respectively.

    Args:
    - base_path (str): Path to the base directory containing the toy_data folder.
    - images_data_path (str): Path to the images_data folder.
    - masks_data_path (str): Path to the masks_data folder.
    """
    toy_data_path = os.path.join(base_path, 'toy_data')

    # Traverse through all sample folders in toy_data
    for sample_folder in os.listdir(toy_data_path):
        sample_path = os.path.join(toy_data_path, sample_folder)

        if os.path.isdir(sample_path):
            # Copy images
            images_folder = os.path.join(sample_path, 'images')
            if os.path.exists(images_folder):
                for image_file in os.listdir(images_folder):
                    if image_file.endswith('.png'):
                        source_image_path = os.path.join(images_folder, image_file)
                        target_image_path = os.path.join(images_data_path, f"{sample_folder}_{image_file}")
                        shutil.copy(source_image_path, target_image_path)
                        print(f"Copied image: {source_image_path} to {target_image_path}")

            # Copy masks
            masks_folder = os.path.join(sample_path, 'merged_masks')
            if os.path.exists(masks_folder):
                for mask_file in os.listdir(masks_folder):
                    if mask_file.endswith('.png'):
                        source_mask_path = os.path.join(masks_folder, mask_file)
                        target_mask_path = os.path.join(masks_data_path, f"{sample_folder}_{mask_file}")
                        shutil.copy(source_mask_path, target_mask_path)
                        print(f"Copied mask: {source_mask_path} to {target_mask_path}")

# %%
base_path = '/content/data'
images_data_path, masks_data_path = create_folders(base_path)
copy_images_and_masks(base_path, images_data_path, masks_data_path)
# Out:
# Created folders: /content/data/images_data and /content/data/masks_data
# Copied image: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379/images/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379.png to /content/data/images_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379.png
# Copied mask: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379/merged_masks/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask.png to /content/data/masks_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask.png
# Copied image: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855/images/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855.png to /content/data/images_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855.png
# Copied mask: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask.png to /content/data/masks_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask.png
# Copied image: /content/data/toy_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868/images/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868.png to /content/data/images_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868.png
# Copied mask: /content/data/toy_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868/merged_masks/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_merged_mask.png to /content/data/masks_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_merged_mask.png
# Copied image: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_2/images/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_1_0.png to /content/data/images_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_2_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_1_0.png
# Copied mask: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_2/merged_masks/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_1_0.png to /content/data/masks_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_2_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_3/images/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_2_0.png to /content/data/images_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_3_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_2_0.png
# Copied mask: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_3/merged_masks/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_2_0.png to /content/data/masks_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_3_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_augmented_4/images/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_aug_3_0.png to /content/data/images_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_augmented_4_c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_aug_3_0.png
# Copied mask: /content/data/toy_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_augmented_4/merged_masks/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_merged_mask_aug_3_0.png to /content/data/masks_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_augmented_4_c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_augmented_1/images/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_aug_0_0.png to /content/data/images_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_augmented_1_f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_aug_0_0.png
# Copied mask: /content/data/toy_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_augmented_1/merged_masks/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_merged_mask_aug_0_0.png to /content/data/masks_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_augmented_1_f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_4/images/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_3_0.png to /content/data/images_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_4_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_3_0.png
# Copied mask: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_4/merged_masks/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_3_0.png to /content/data/masks_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_4_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_2/images/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_1_0.png to /content/data/images_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_2_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_1_0.png
# Copied mask: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_2/merged_masks/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_1_0.png to /content/data/masks_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_2_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_augmented_4/images/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_aug_3_0.png to /content/data/images_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_augmented_4_ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_aug_3_0.png
# Copied mask: /content/data/toy_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_augmented_4/merged_masks/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_merged_mask_aug_3_0.png to /content/data/masks_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_augmented_4_ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_4/images/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_3_0.png to /content/data/images_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_4_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_3_0.png
# Copied mask: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_4/merged_masks/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_3_0.png to /content/data/masks_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_4_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_5/images/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_4_0.png to /content/data/images_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_5_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_4_0.png
# Copied mask: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_5/merged_masks/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_4_0.png to /content/data/masks_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_5_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee/images/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee.png to /content/data/images_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee.png
# Copied mask: /content/data/toy_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee/merged_masks/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_merged_mask.png to /content/data/masks_data/ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_ee927e8255096971ddae1bd975cf80c4ad7c847c82d0b5f5dd2ddfe5407007ee_merged_mask.png
# Copied image: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_1/images/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_0_0.png to /content/data/images_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_1_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_0_0.png
# Copied mask: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_1/merged_masks/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_0_0.png to /content/data/masks_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_1_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_2/images/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_1_0.png to /content/data/images_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_2_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_1_0.png
# Copied mask: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_2/merged_masks/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_1_0.png to /content/data/masks_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_2_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47/images/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47.png to /content/data/images_data/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47_27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47.png
# Copied mask: /content/data/toy_data/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47/merged_masks/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47_merged_mask.png to /content/data/masks_data/27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47_27c30f9011492f234e4587c9a4b53c787037d486f658821196fe354240ac3c47_merged_mask.png
# Copied image: /content/data/toy_data/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_augmented_3/images/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_aug_2_0.png to /content/data/images_data/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_augmented_3_4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_aug_2_0.png
# Copied mask: /content/data/toy_data/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_augmented_3/merged_masks/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_merged_mask_aug_2_0.png to /content/data/masks_data/4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_augmented_3_4d40de30a3db3bc4f241cb7f48e8497c11e8f20a99bf55788bdce17242029745_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380/images/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380.png to /content/data/images_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380.png
# Copied mask: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380/merged_masks/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask.png to /content/data/masks_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask.png
# Copied image: /content/data/toy_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_2/images/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_aug_1_0.png to /content/data/images_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_2_ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_aug_1_0.png
# Copied mask: /content/data/toy_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_2/merged_masks/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_merged_mask_aug_1_0.png to /content/data/masks_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_2_ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_3/images/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_2_0.png to /content/data/images_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_3_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_2_0.png
# Copied mask: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_3/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_2_0.png to /content/data/masks_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_3_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_5/images/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_4_0.png to /content/data/images_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_5_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_4_0.png
# Copied mask: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_5/merged_masks/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_4_0.png to /content/data/masks_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_5_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55/images/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55.png to /content/data/images_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55.png
# Copied mask: /content/data/toy_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55/merged_masks/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_merged_mask.png to /content/data/masks_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_merged_mask.png
# Copied image: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_1/images/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_0_0.png to /content/data/images_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_1_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_0_0.png
# Copied mask: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_1/merged_masks/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_0_0.png to /content/data/masks_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_1_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_augmented_4/images/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_aug_3_0.png to /content/data/images_data/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_augmented_4_5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_aug_3_0.png
# Copied mask: /content/data/toy_data/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_augmented_4/merged_masks/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_merged_mask_aug_3_0.png to /content/data/masks_data/5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_augmented_4_5ddbfba2519484316e4b7ccabfa605e6e6fd96c3d87ac8cdfd2c134571a15311_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066/images/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066.png to /content/data/images_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066.png
# Copied mask: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066/merged_masks/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask.png to /content/data/masks_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask.png
# Copied image: /content/data/toy_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_3/images/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_aug_2_0.png to /content/data/images_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_3_5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_aug_2_0.png
# Copied mask: /content/data/toy_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_3/merged_masks/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_merged_mask_aug_2_0.png to /content/data/masks_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_3_5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_5/images/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_4_0.png to /content/data/images_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_5_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_4_0.png
# Copied mask: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_5/merged_masks/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_4_0.png to /content/data/masks_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_5_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_3/images/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_2_0.png to /content/data/images_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_3_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_2_0.png
# Copied mask: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_3/merged_masks/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_2_0.png to /content/data/masks_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_3_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_augmented_4/images/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_aug_3_0.png to /content/data/images_data/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_augmented_4_8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_aug_3_0.png
# Copied mask: /content/data/toy_data/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_augmented_4/merged_masks/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_merged_mask_aug_3_0.png to /content/data/masks_data/8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_augmented_4_8d9b4205ddb10fa49a2973b4f3a2dc6923407ae015081e1a52c4b4c2fe8faa53_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5/images/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5.png to /content/data/images_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5.png
# Copied mask: /content/data/toy_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5/merged_masks/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_merged_mask.png to /content/data/masks_data/f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_f93ec5e683d81005ffc2a84a1c0299b2406ad14b764b824e013f7ca3a13833b5_merged_mask.png
# Copied image: /content/data/toy_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_1/images/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_aug_0_0.png to /content/data/images_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_1_5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_aug_0_0.png
# Copied mask: /content/data/toy_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_1/merged_masks/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_merged_mask_aug_0_0.png to /content/data/masks_data/5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_augmented_1_5488e8df5440ee5161fdfae3aeccd2ee396636430065c90e3f1f73870a975991_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_augmented_2/images/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_aug_1_0.png to /content/data/images_data/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_augmented_2_e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_aug_1_0.png
# Copied mask: /content/data/toy_data/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_augmented_2/merged_masks/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_merged_mask_aug_1_0.png to /content/data/masks_data/e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_augmented_2_e216ec5063d3562b793e434c491051bd8867f6c2e571e41137c7c560cc0e6a03_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_augmented_2/images/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_aug_1_0.png to /content/data/images_data/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_augmented_2_60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_aug_1_0.png
# Copied mask: /content/data/toy_data/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_augmented_2/merged_masks/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_merged_mask_aug_1_0.png to /content/data/masks_data/60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_augmented_2_60cb718759bff13f81c4055a7679e81326f78b6a193a2d856546097c949b20ff_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_4/images/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_aug_3_0.png to /content/data/images_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_4_29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_aug_3_0.png
# Copied mask: /content/data/toy_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_4/merged_masks/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_merged_mask_aug_3_0.png to /content/data/masks_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_4_29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_augmented_5/images/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_aug_4_0.png to /content/data/images_data/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_augmented_5_df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_aug_4_0.png
# Copied mask: /content/data/toy_data/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_augmented_5/merged_masks/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_merged_mask_aug_4_0.png to /content/data/masks_data/df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_augmented_5_df9a4212ecb67bb4e58eba62f293b91f9d6f1dde73e38fa891c75661d419fc97_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_augmented_4/images/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_aug_3_0.png to /content/data/images_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_augmented_4_648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_aug_3_0.png
# Copied mask: /content/data/toy_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_augmented_4/merged_masks/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_merged_mask_aug_3_0.png to /content/data/masks_data/648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_augmented_4_648636ee314d7bdba3ab2fc0fe49a863de35c3e2caf619039f678df67b526868_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_augmented_2/images/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_aug_1_0.png to /content/data/images_data/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_augmented_2_76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_aug_1_0.png
# Copied mask: /content/data/toy_data/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_augmented_2/merged_masks/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_merged_mask_aug_1_0.png to /content/data/masks_data/76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_augmented_2_76faaed50ed6ea6814ac36199964b86fb09ba7f41a6f213bceaa80d625adc2e1_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552/images/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.png to /content/data/images_data/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552_00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552.png
# Copied mask: /content/data/toy_data/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552/merged_masks/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552_merged_mask.png to /content/data/masks_data/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552_00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552_merged_mask.png
# Copied image: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_3/images/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_2_0.png to /content/data/images_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_3_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_2_0.png
# Copied mask: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_3/merged_masks/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_2_0.png to /content/data/masks_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_3_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_1/images/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_0_0.png to /content/data/images_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_1_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_0_0.png
# Copied mask: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_1/merged_masks/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_0_0.png to /content/data/masks_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_1_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_2/images/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_aug_1_0.png to /content/data/images_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_2_958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_aug_1_0.png
# Copied mask: /content/data/toy_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_2/merged_masks/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_merged_mask_aug_1_0.png to /content/data/masks_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_2_958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932/images/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932.png to /content/data/images_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932.png
# Copied mask: /content/data/toy_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932/merged_masks/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_merged_mask.png to /content/data/masks_data/c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_c304a1fdf3bca2f4b4580d2cac59942e2224a7678001bf5ed9d9852f57708932_merged_mask.png
# Copied image: /content/data/toy_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_4/images/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_aug_3_0.png to /content/data/images_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_4_ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_aug_3_0.png
# Copied mask: /content/data/toy_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_4/merged_masks/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_merged_mask_aug_3_0.png to /content/data/masks_data/ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_augmented_4_ff599c7301daa1f783924ac8cbe3ce7b42878f15a39c2d19659189951f540f48_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_augmented_5/images/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_aug_4_0.png to /content/data/images_data/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_augmented_5_2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_aug_4_0.png
# Copied mask: /content/data/toy_data/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_augmented_5/merged_masks/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_merged_mask_aug_4_0.png to /content/data/masks_data/2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_augmented_5_2246874c8b5ba218d01ad8153a201ad4660195f3e4c65da6b9d4ccaf82cb7edf_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_augmented_4/images/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_aug_3_0.png to /content/data/images_data/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_augmented_4_edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_aug_3_0.png
# Copied mask: /content/data/toy_data/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_augmented_4/merged_masks/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_merged_mask_aug_3_0.png to /content/data/masks_data/edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_augmented_4_edd36ed822e7ed760ff73e0524df22aa5bf5c565efcdc6c39603239c0896e7a8_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_5/images/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_4_0.png to /content/data/images_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_5_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_4_0.png
# Copied mask: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_5/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_4_0.png to /content/data/masks_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_5_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_3/images/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_2_0.png to /content/data/images_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_3_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_2_0.png
# Copied mask: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_3/merged_masks/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_2_0.png to /content/data/masks_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_3_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_5/images/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_4_0.png to /content/data/images_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_5_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_4_0.png
# Copied mask: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_5/merged_masks/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_4_0.png to /content/data/masks_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_5_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_2/images/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_1_0.png to /content/data/images_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_2_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_1_0.png
# Copied mask: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_2/merged_masks/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_1_0.png to /content/data/masks_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_2_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_3/images/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_2_0.png to /content/data/images_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_3_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_2_0.png
# Copied mask: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_3/merged_masks/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_2_0.png to /content/data/masks_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_3_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_2/images/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_aug_1_0.png to /content/data/images_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_2_4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_aug_1_0.png
# Copied mask: /content/data/toy_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_2/merged_masks/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_merged_mask_aug_1_0.png to /content/data/masks_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_2_4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_1/images/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_0_0.png to /content/data/images_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_1_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_0_0.png
# Copied mask: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_1/merged_masks/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_0_0.png to /content/data/masks_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_1_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_2/images/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_1_0.png to /content/data/images_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_2_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_1_0.png
# Copied mask: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_2/merged_masks/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_1_0.png to /content/data/masks_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_2_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_3/images/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_aug_2_0.png to /content/data/images_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_3_958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_aug_2_0.png
# Copied mask: /content/data/toy_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_3/merged_masks/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_merged_mask_aug_2_0.png to /content/data/masks_data/958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_augmented_3_958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_4/images/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_aug_3_0.png to /content/data/images_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_4_20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_aug_3_0.png
# Copied mask: /content/data/toy_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_4/merged_masks/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_merged_mask_aug_3_0.png to /content/data/masks_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_4_20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_augmented_2/images/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_aug_1_0.png to /content/data/images_data/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_augmented_2_319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_aug_1_0.png
# Copied mask: /content/data/toy_data/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_augmented_2/merged_masks/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_merged_mask_aug_1_0.png to /content/data/masks_data/319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_augmented_2_319b6cb8b0d24b38db5e3c6fbb13b062e2766d9af5ff9bccb8f439ac0d870e52_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_1/images/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_aug_0_0.png to /content/data/images_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_1_4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_aug_0_0.png
# Copied mask: /content/data/toy_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_1/merged_masks/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_merged_mask_aug_0_0.png to /content/data/masks_data/4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_augmented_1_4bf6a5ec42032bb8dbbb10d25fdc5211b2fe1ce44b6e577ef89dbda17697d819_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_augmented_3/images/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_aug_2_0.png to /content/data/images_data/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_augmented_3_449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_aug_2_0.png
# Copied mask: /content/data/toy_data/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_augmented_3/merged_masks/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_merged_mask_aug_2_0.png to /content/data/masks_data/449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_augmented_3_449a9c32e53a37c8a86e01c199155c8da3958b631088e10f6fe43c2119defe51_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_2/images/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_1_0.png to /content/data/images_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_2_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_aug_1_0.png
# Copied mask: /content/data/toy_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_2/merged_masks/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_1_0.png to /content/data/masks_data/094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_augmented_2_094afe36759e7daffe12188ab5987581d405b06720f1d5acf3f2614f404df380_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96/images/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96.png to /content/data/images_data/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96_bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96.png
# Copied mask: /content/data/toy_data/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96/merged_masks/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96_merged_mask.png to /content/data/masks_data/bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96_bff985591dd5d6303018a6e9a3dcfb336771a414ad4605c24ce1c1155fc86a96_merged_mask.png
# Copied image: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_1/images/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_0_0.png to /content/data/images_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_1_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_aug_0_0.png
# Copied mask: /content/data/toy_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_1/merged_masks/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_0_0.png to /content/data/masks_data/f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_augmented_1_f81ca7ee25e733ff37240c34c8e3044d9937bb0166e315952ebde3f237ecb86f_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_4/images/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_3_0.png to /content/data/images_data/8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_augmented_4_8ecdb93582b2d5270457b36651b62776256ade3aaa2d7432ae65c14f07432d49_aug_3_0.png
# ...
# Copied image: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7/images/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7.png to /content/data/images_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7.png
# Copied mask: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7/merged_masks/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask.png to /content/data/masks_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask.png
# Copied image: /content/data/toy_data/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_augmented_3/images/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_aug_2_0.png to /content/data/images_data/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_augmented_3_bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_aug_2_0.png
# Copied mask: /content/data/toy_data/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_augmented_3/merged_masks/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_merged_mask_aug_2_0.png to /content/data/masks_data/bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_augmented_3_bde3727f3a9e8b2b58f383ebc762b2157eb50cdbff23e69b025418b43967556b_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_augmented_1/images/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_aug_0_0.png to /content/data/images_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_augmented_1_317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_aug_0_0.png
# Copied mask: /content/data/toy_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_augmented_1/merged_masks/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_merged_mask_aug_0_0.png to /content/data/masks_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_augmented_1_317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_merged_mask_aug_0_0.png
# Copied image: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_4/images/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_3_0.png to /content/data/images_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_4_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_aug_3_0.png
# Copied mask: /content/data/toy_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_4/merged_masks/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_3_0.png to /content/data/masks_data/77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_augmented_4_77ceeb87f560775ac150b8b9b09684ed3e806d0af6f26cce8f10c5fc280f5df2_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_augmented_2/images/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_aug_1_0.png to /content/data/images_data/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_augmented_2_aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_aug_1_0.png
# Copied mask: /content/data/toy_data/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_augmented_2/merged_masks/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_merged_mask_aug_1_0.png to /content/data/masks_data/aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_augmented_2_aaa52100fafaa50877e777229cdf6cde7c422f145ff6719449b80631d9a3b0f6_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_4/images/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_3_0.png to /content/data/images_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_4_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_aug_3_0.png
# Copied mask: /content/data/toy_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_4/merged_masks/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_3_0.png to /content/data/masks_data/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_augmented_4_00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_3/images/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_aug_2_0.png to /content/data/images_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_3_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_aug_2_0.png
# Copied mask: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_3/merged_masks/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask_aug_2_0.png to /content/data/masks_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_3_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_2/images/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_1_0.png to /content/data/images_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_2_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_aug_1_0.png
# Copied mask: /content/data/toy_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_2/merged_masks/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_1_0.png to /content/data/masks_data/d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_augmented_2_d7fc0d0a7339211f2433829c6553b762e2b9ef82cfe218d58ecae6643fa8e9c7_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_4/images/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_aug_3_0.png to /content/data/images_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_4_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_aug_3_0.png
# Copied mask: /content/data/toy_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_4/merged_masks/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask_aug_3_0.png to /content/data/masks_data/193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_augmented_4_193ffaa5272d5c421ae02130a64d98ad120ec70e4ed97a72cdcd4801ce93b066_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_5/images/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_aug_4_0.png to /content/data/images_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_5_29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_aug_4_0.png
# Copied mask: /content/data/toy_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_5/merged_masks/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_merged_mask_aug_4_0.png to /content/data/masks_data/29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_augmented_5_29ea4f6eb4545f43868a9b40a60000426bf8dfd9d062546656a37bd2a2aaf9ec_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_4/images/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_3_0.png to /content/data/images_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_4_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_3_0.png
# Copied mask: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_4/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_3_0.png to /content/data/masks_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_4_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_2/images/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_1_0.png to /content/data/images_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_2_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_aug_1_0.png
# Copied mask: /content/data/toy_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_2/merged_masks/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_1_0.png to /content/data/masks_data/866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_augmented_2_866a8cba7bfe1ea73e383d6cf492e53752579140c8b833bb56839a55bf79d855_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_4/images/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_3_0.png to /content/data/images_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_4_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_aug_3_0.png
# Copied mask: /content/data/toy_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_4/merged_masks/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_3_0.png to /content/data/masks_data/91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_augmented_4_91cc2e0d4d6e2c1ad59a8d63bcbe3e2ea8bc7f8e642e942a0113450181e73379_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_augmented_2/images/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_aug_1_0.png to /content/data/images_data/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_augmented_2_5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_aug_1_0.png
# Copied mask: /content/data/toy_data/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_augmented_2/merged_masks/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_merged_mask_aug_1_0.png to /content/data/masks_data/5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_augmented_2_5d58600efa0c2667ec85595bf456a54e2bd6e6e9a5c0dff42d807bc9fe2b822e_merged_mask_aug_1_0.png
# Copied image: /content/data/toy_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_augmented_5/images/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_aug_4_0.png to /content/data/images_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_augmented_5_f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_aug_4_0.png
# Copied mask: /content/data/toy_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_augmented_5/merged_masks/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_merged_mask_aug_4_0.png to /content/data/masks_data/f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_augmented_5_f8e74d4006dd68c1dbe68df7be905835e00d8ba4916f3b18884509a15fdc0b55_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_4/images/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_3_0.png to /content/data/images_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_4_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_aug_3_0.png
# Copied mask: /content/data/toy_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_4/merged_masks/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_3_0.png to /content/data/masks_data/f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_augmented_4_f534b43bf37ff946a310a0f08315d76c3fb3394681cf523acef7c0682240072a_merged_mask_aug_3_0.png
# Copied image: /content/data/toy_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_5/images/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_aug_4_0.png to /content/data/images_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_5_20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_aug_4_0.png
# Copied mask: /content/data/toy_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_5/merged_masks/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_merged_mask_aug_4_0.png to /content/data/masks_data/20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_augmented_5_20c37b1ad2f510ed7396969e855fe93d0d05611738f6e706e8ca1d1aed3ded45_merged_mask_aug_4_0.png
# Copied image: /content/data/toy_data/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_augmented_3/images/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_aug_2_0.png to /content/data/images_data/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_augmented_3_8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_aug_2_0.png
# Copied mask: /content/data/toy_data/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_augmented_3/merged_masks/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_merged_mask_aug_2_0.png to /content/data/masks_data/8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_augmented_3_8f6597cd978c060378177df76e554d0578b97eab471e237dbe0adc0dd0d93d63_merged_mask_aug_2_0.png
# Copied image: /content/data/toy_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b/images/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b.png to /content/data/images_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b.png
# Copied mask: /content/data/toy_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b/merged_masks/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_merged_mask.png to /content/data/masks_data/317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_317832f90f02c5e916b2ac0f3bcb8da9928d8e400b747b2c68e544e56adacf6b_merged_mask.png
# Copied image: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_4/images/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_3_0.png to /content/data/images_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_4_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_aug_3_0.png
# Copied mask: /content/data/toy_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_4/merged_masks/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_3_0.png to /content/data/masks_data/f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_augmented_4_f4b7c24baf69b8752c49d0eb5db4b7b5e1524945d48e54925bff401d5658045d_merged_mask_aug_3_0.png

# %%
# !pip install "opencv-python-headless<4.3"
# !pip install cellpose
# Out:
# Collecting opencv-python-headless<4.3
#   Downloading opencv_python_headless-3.4.18.65-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (45.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless<4.3) (1.25.2)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.3.1 requires opencv-python-headless>=4.1.1, but you have opencv-python-headless 3.4.18.65 which is incompatible.
# qudida 0.0.4 requires opencv-python-headless>=4.0.1, but you have opencv-python-headless 3.4.18.65 which is incompatible.
# Successfully installed opencv-python-headless-3.4.18.65
# Collecting cellpose
#   Downloading cellpose-3.0.8-py3-none-any.whl (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.0/205.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from cellpose) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from cellpose) (1.11.4)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from cellpose) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (from cellpose) (2024.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from cellpose) (4.66.4)
# Requirement already satisfied: numba>=0.53.0 in /usr/local/lib/python3.10/dist-packages (from cellpose) (0.58.1)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.10/dist-packages (from cellpose) (0.41.1)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.10/dist-packages (from cellpose) (2.2.1+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from cellpose) (3.4.18.65)
# Collecting fastremap (from cellpose)
#   Downloading fastremap-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 64.8 MB/s eta 0:00:00
# Collecting imagecodecs (from cellpose)
#   Downloading imagecodecs-2024.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.6/39.6 MB 13.1 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/roifile/
# Collecting roifile (from cellpose)
#   Downloading roifile-2024.3.20-py3-none-any.whl (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.6->cellpose)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.6->cellpose)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.6->cellpose)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.6->cellpose)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.6->cellpose)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.6->cellpose)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.6->cellpose)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.6->cellpose)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.6->cellpose)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.6->cellpose)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.6->cellpose)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->cellpose) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->cellpose)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6->cellpose) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6->cellpose) (1.3.0)
# Installing collected packages: roifile, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, imagecodecs, fastremap, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, cellpose
# Successfully installed cellpose-3.0.8 fastremap-1.14.1 imagecodecs-2024.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 roifile-2024.3.20

# %%
# !nvcc --version
# !nvidia-smi

import os, shutil
import numpy as np
import matplotlib.pyplot as plt
from cellpose import core, utils, io, models, metrics
from glob import glob

use_GPU = core.use_gpu()
yn = ['NO', 'YES']
print(f'>>> GPU activated? {yn[use_GPU]}')
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# Sun May 19 09:31:51 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+
# >>> GPU activated? YES

# %%
import os
from skimage import io
import numpy as np
from cellpose import models, utils, io as cp_io, train

# Paths to images and masks
train_dir = "/content/data"  # Path to the directory containing training images and masks
test_dir = None  # Set to None if you do not have a separate test directory

# Model name and path
initial_model = "cyto"  # Choose the appropriate pretrained model type
model_name = "CP_custom_model"  # Name of the new model

# Training parameters
n_epochs = 10  # Number of epochs

Channel_to_use_for_training = "Grayscale"  # Choose the primary channel

# If you have a secondary channel, specify it here; otherwise, set to "None"
Second_training_channel = "None"

# Advanced parameters
Use_Default_Advanced_Parameters = True  # Whether to use default advanced parameters
learning_rate = 0.1  # Default learning rate
weight_decay = 0.0001  # Default weight decay

if Use_Default_Advanced_Parameters:
    learning_rate = 0.1
    weight_decay = 0.0001

# Checking if a model with the same name already exists, and delete if so
model_path = os.path.join(train_dir, 'models')
if os.path.exists(os.path.join(model_path, model_name)):
    print(f"!! WARNING: {model_name} already exists and will be deleted !!")
    os.remove(os.path.join(model_path, model_name))

# Match the channel to number
chan = 0 if Channel_to_use_for_training == "Grayscale" else {"Red": 1, "Green": 2, "Blue": 3}.get(Channel_to_use_for_training, 0)
chan2 = 0 if Second_training_channel == "None" else {"Red": 1, "Green": 2, "Blue": 3}.get(Second_training_channel, 0)

if initial_model == 'scratch':
    initial_model = None

# Start logger to see training across epochs
logger = cp_io.logger_setup()

# Define Cellpose model (without size model)
model = models.CellposeModel(gpu=True, model_type=initial_model)

# Set channels
channels = [chan, chan2]

# Load images and masks
def load_images_and_masks(image_path, mask_path):
    images = []
    masks = []

    for filename in sorted(os.listdir(image_path)):
        if filename.endswith('.png'):
            image = io.imread(os.path.join(image_path, filename))
            images.append(image)

    for filename in sorted(os.listdir(mask_path)):
        if filename.endswith('.png'):
            mask = io.imread(os.path.join(mask_path, filename))
            masks.append(mask)

    return images, masks

image_path = os.path.join(train_dir, 'images_data')
mask_path = os.path.join(train_dir, 'masks_data')
train_data, train_labels = load_images_and_masks(image_path, mask_path)

# Perform sanity checks on the loaded data
print(f"Loaded {len(train_data)} training images")
print(f"Loaded {len(train_labels)} training masks")

if len(train_data) == 0 or len(train_labels) == 0:
    raise ValueError("No images or masks found. Please check the dataset directory structure and file names.")

# If you have a separate test set, load it; otherwise, set test_data and test_labels to None
if test_dir:
    test_image_path = os.path.join(test_dir, 'images')
    test_mask_path = os.path.join(test_dir, 'masks')
    test_data, test_labels = load_images_and_masks(test_image_path, test_mask_path)
else:
    test_data, test_labels = None, None

# Perform training
new_model_path = train.train_seg(
    model.net,
    train_data=train_data,
    train_labels=train_labels,
    test_data=test_data,
    test_labels=test_labels,
    channels=channels,
    save_path=train_dir,
    n_epochs=n_epochs,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    SGD=True,
    nimg_per_epoch=8,
    model_name=model_name,
    min_train_masks=1
)

# Diameter of labels in training images
diam_labels = model.net.diam_labels.item()

print("Model training completed and saved successfully!")
# Out:
# Loaded 300 training images
# Loaded 300 training masks
# 100%|██████████| 300/300 [02:07<00:00,  2.36it/s]
# 100%|██████████| 300/300 [00:00<00:00, 1167.25it/s]
# Model training completed and saved successfully!

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io as skio

# Define paths
model_path = '/content/data/models/CP_custom_model'
image_path = '/content/data/stage1_test/0114f484a16c152baa2d82fdd43740880a762c93f436c8988ac461c5c9dbe7d5/images/0114f484a16c152baa2d82fdd43740880a762c93f436c8988ac461c5c9dbe7d5.png'

# Load the trained model
model = models.CellposeModel(pretrained_model=model_path, gpu=True)

# Define channels to use
channels = [0, 0]  # Modify if you have specific channels to use

# %%
# Load the image
image = skio.imread(image_path)

# Optionally, preprocess the image
# Example: stretch contrast if needed (uncomment if necessary)
# image = stretch_contrast(image)

# Display the image
plt.imshow(image, cmap='gray')
plt.title("Input Image")
plt.show()

# %%
# Run the model on the image
masks, flows, styles = model.eval(image, channels=channels, do_3D=False)

# 'masks' is the segmentation result

# %%
# Visualize the masks
plt.imshow(image, cmap='gray')
plt.imshow(masks, alpha=0.5)  # Overlay masks with some transparency
plt.title("Segmented Image")
plt.show()
